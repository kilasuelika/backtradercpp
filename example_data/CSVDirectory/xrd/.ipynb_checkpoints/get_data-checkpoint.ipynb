# %%
import akshare as ak
import glob
import time

# %%
codes=[s[-13:-4] for s in glob.glob("../raw/*")]
codes

for cd in codes:
    df = ak.stock_history_dividend_detail(symbol=cd[:6], indicator="分红")
    df.to_csv(f"{cd}.csv")
    
    time.sleep(5)
# Out:
# 000021
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       4 for cd in codes:
#       5     print(cd[:6])
# ----> 6     df = ak.stock_history_dividend_detail(symbol=cd[:6], indicator="分红")
#       7     df.to_csv(f"{cd}.csv")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\akshare\stock_fundamental\stock_finance.py:168, in stock_history_dividend_detail(symbol, indicator, date)
#     166 url = f"http://vip.stock.finance.sina.com.cn/corp/go.php/vISSUE_ShareBonus/stockid/{symbol}.phtml"
#     167 r = requests.get(url)
# --> 168 temp_df = pd.read_html(r.text)[12]
#     169 temp_df.columns = [item[2] for item in temp_df.columns.tolist()]
#     170 temp_df.columns = [
#     171     "公告日期",
#     172     "送股",
#    (...)
#     179     "查看详细",
#     180 ]
#
# ...

# %%
stock_history_dividend_detail_df = ak.stock_history_dividend_detail(symbol="600012", indicator="分红")
print(stock_history_dividend_detail_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 stock_history_dividend_detail_df = ak.stock_history_dividend_detail(symbol="600012", indicator="分红")
#       2 print(stock_history_dividend_detail_df)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\akshare\stock_fundamental\stock_finance.py:168, in stock_history_dividend_detail(symbol, indicator, date)
#     166 url = f"http://vip.stock.finance.sina.com.cn/corp/go.php/vISSUE_ShareBonus/stockid/{symbol}.phtml"
#     167 r = requests.get(url)
# --> 168 temp_df = pd.read_html(r.text)[12]
#     169 temp_df.columns = [item[2] for item in temp_df.columns.tolist()]
#     170 temp_df.columns = [
#     171     "公告日期",
#     172     "送股",
#    (...)
#     179     "查看详细",
#     180 ]
#
# ...

# %%
df=ak.stock_history_dividend_detail(symbol=codes[0], indicator="分红")
print(df)
df.to_csv(f"codes[0].csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df=ak.stock_history_dividend_detail(symbol=codes[0], indicator="分红")
#       2 print(df)
#       3 df.to_csv(f"codes[0].csv")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\akshare\stock_fundamental\stock_finance.py:168, in stock_history_dividend_detail(symbol, indicator, date)
#     166 url = f"http://vip.stock.finance.sina.com.cn/corp/go.php/vISSUE_ShareBonus/stockid/{symbol}.phtml"
#     167 r = requests.get(url)
# --> 168 temp_df = pd.read_html(r.text)[12]
#     169 temp_df.columns = [item[2] for item in temp_df.columns.tolist()]
#     170 temp_df.columns = [
#     171     "公告日期",
#     172     "送股",
#    (...)
#     179     "查看详细",
#     180 ]
#
# ...
